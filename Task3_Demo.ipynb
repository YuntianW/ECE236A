# %%
from utils import *
from MySolution import *
from matplotlib import pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
m = MyLabelSelection(0.25)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

trainX = prepare_mnist_data()["trainX"]
selected = m.select(trainX)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250/250 [00:16<00:00, 15.52it/s]

# %%
len(selected)
# Out:
# 35

# %%
norm_X = StandardScaler().fit_transform(trainX)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(norm_X)
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.scatter(X_pca[selected, 0], X_pca[selected, 1])

# %%
X_pca
# Out:
# array([[-3.1372916 , -0.09618801],
#        [-0.56311958, -1.51710357],
#        [-3.81744674,  0.6393352 ],
#        ...,
#        [-1.38252235,  1.04099624],
#        [-2.56806497, -1.98989   ],
#        [-0.13869353,  0.44696649]])

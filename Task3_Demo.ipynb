# %%
from utils import *
from MySolution import *
from matplotlib import pyplot as plt
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
m = MyLabelSelection(0.25)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

trainX = prepare_mnist_data()["trainX"]

# %%
selected = m.select(trainX)

# %%
len(selected)
# Out:
# 35

# %%
norm_X = StandardScaler().fit_transform(trainX)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(norm_X)
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.scatter(X_pca[selected, 0], X_pca[selected, 1])

# %%
m = MyLabelSelection(6/1000)
selected = m.select(trainX)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 17.03it/s]

# %%
fig, axes = plt.subplots(1, len(selected), figsize=(15, 5))
for i, j in enumerate(selected):
    axes[i].imshow(trainX[j, :].reshape(28, 28))


plt.tight_layout()

# Show the plot
plt.show()
